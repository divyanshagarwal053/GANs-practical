# %%
# %cd /content/drive/MyDrive/GANs_practical
# Out:
# /content/drive/MyDrive/GANs_practical

# %%
# %cd ESRGAN-master
# Out:
# /content/drive/MyDrive/GANs_practical/ESRGAN-master

# %%
# !python test.py
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 download
# 2 download (1)
# 3 images
# 4 images (1)
