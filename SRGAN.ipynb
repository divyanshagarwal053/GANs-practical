# %%
# %cd /content/drive/MyDrive/GANs_practical
# Out:
# /content/drive/MyDrive/GANs_practical

# %%
# %cd /content/drive/MyDrive/GANs_practical/SRGAN-Super-Resolution-GAN-master
# Out:
# /content/drive/MyDrive/GANs_practical/SRGAN-Super-Resolution-GAN-master

# %%
# !pip install --upgrade scikit-image
# Out:
# ...
#   Using cached scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
# ...
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/GANs_practical/SRGAN-Super-Resolution-GAN-master'

# %%
# !python main.py --mode test_only --LR_path test_data --generator_path pretrained_models/SRGAN.pt
